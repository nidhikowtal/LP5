# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Loading the dataset

# %%
train_df = pd.read_csv('Google_Stock_Price_Train.csv')
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   object
#  5   Volume  1258 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 59.1+ KB

# %%
test_df = pd.read_csv('Google_Stock_Price_Test.csv')
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Open    20 non-null     float64
#  2   High    20 non-null     float64
#  3   Low     20 non-null     float64
#  4   Close   20 non-null     float64
#  5   Volume  20 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 1.1+ KB

# %% [markdown]
# #### Choosing column 'open' for predicition

# %%
train = train_df.loc[:,["Open"]].values
train.shape
# Out:
# (1258, 1)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
train_scaled = scaler.fit_transform(train)

# %%
plt.plot(train_scaled)
plt.ylabel("Standardized Values")
plt.xlabel("Time->")
plt.show()

# %% [markdown]
# ### Create data structure to train model
# Taking reference of past 60 days to predict future stock price
# x_train will have data of 60 days prior to current date and y_train will have price on current date

# %%
x_train = []
y_train = []
time = 60
for i in range(60,train_scaled.shape[0]):
    x_train.append(train_scaled[i-60:i,0])
    y_train.append(train_scaled[i,0])
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train.shape,y_train.shape
# Out:
# ((1198, 60), (1198,))

# %%
x_train = np.reshape(x_train,newshape=(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1198, 60, 1)

# %% [markdown]
# ### Build model

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN,Dropout

# %%
model = Sequential()

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50))
model.add(Dropout(0.2))

model.add(Dense(units=1))

model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 60, 50)            2600
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 60, 50)            5050
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  simple_rnn_2 (SimpleRNN)    (None, 60, 50)            5050
#
#  dropout_2 (Dropout)         (None, 60, 50)            0
#
#  simple_rnn_3 (SimpleRNN)    (None, 50)                5050
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 17,801
# Trainable params: 17,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=100,batch_size=30,validation_split=0.05)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 16s 142ms/step - loss: 0.3755 - val_loss: 0.0016
# Epoch 2/100
# 38/38 [==============================] - 4s 99ms/step - loss: 0.2083 - val_loss: 0.0072
# Epoch 3/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.1487 - val_loss: 8.4308e-04
# Epoch 4/100
# 38/38 [==============================] - 4s 96ms/step - loss: 0.1135 - val_loss: 9.4652e-04
# Epoch 5/100
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0975 - val_loss: 0.0164
# Epoch 6/100
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0849 - val_loss: 7.6924e-04
# Epoch 7/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0646 - val_loss: 0.0038
# Epoch 8/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0568 - val_loss: 0.0057
# Epoch 9/100
# 38/38 [==============================] - 4s 111ms/step - loss: 0.0464 - val_loss: 0.0029
# Epoch 10/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0406 - val_loss: 0.0083
# Epoch 11/100
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0344 - val_loss: 0.0036
# Epoch 12/100
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0329 - val_loss: 0.0199
# Epoch 13/100
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0294 - val_loss: 0.0070
# Epoch 14/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0234 - val_loss: 0.0078
# Epoch 15/100
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0243 - val_loss: 7.1284e-04
# Epoch 16/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.0222 - val_loss: 0.0042
# Epoch 17/100
# 38/38 [==============================] - 4s 110ms/step - loss: 0.0212 - val_loss: 7.0401e-04
# Epoch 18/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0190 - val_loss: 0.0076
# Epoch 19/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0147 - val_loss: 0.0075
# Epoch 20/100
# 38/38 [==============================] - 4s 108ms/step - loss: 0.0149 - val_loss: 0.0064
# Epoch 21/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0147 - val_loss: 0.0079
# Epoch 22/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0124 - val_loss: 0.0113
# Epoch 23/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0122 - val_loss: 0.0083
# Epoch 24/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0116 - val_loss: 5.8923e-04
# Epoch 25/100
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0101 - val_loss: 0.0028
# Epoch 26/100
# 38/38 [==============================] - 4s 109ms/step - loss: 0.0101 - val_loss: 0.0037
# Epoch 27/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0089 - val_loss: 0.0014
# Epoch 28/100
# 38/38 [==============================] - 4s 106ms/step - loss: 0.0082 - val_loss: 0.0012
# Epoch 29/100
# 38/38 [==============================] - 4s 108ms/step - loss: 0.0079 - val_loss: 0.0022
# Epoch 30/100
# 38/38 [==============================] - 4s 105ms/step - loss: 0.0076 - val_loss: 0.0015
# Epoch 31/100
# 38/38 [==============================] - 4s 113ms/step - loss: 0.0073 - val_loss: 0.0011
# Epoch 32/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0073 - val_loss: 6.2777e-04
# Epoch 33/100
# 38/38 [==============================] - 4s 112ms/step - loss: 0.0070 - val_loss: 0.0020
# Epoch 34/100
# 38/38 [==============================] - 4s 114ms/step - loss: 0.0064 - val_loss: 6.4731e-04
# Epoch 35/100
# 38/38 [==============================] - 4s 112ms/step - loss: 0.0058 - val_loss: 6.1074e-04
# Epoch 36/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.0053 - val_loss: 0.0038
# Epoch 37/100
# 38/38 [==============================] - 4s 109ms/step - loss: 0.0059 - val_loss: 5.9900e-04
# Epoch 38/100
# 38/38 [==============================] - 4s 114ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 39/100
# 38/38 [==============================] - 4s 107ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 40/100
# 38/38 [==============================] - 4s 113ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 41/100
# 38/38 [==============================] - 4s 105ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 42/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0047 - val_loss: 6.3914e-04
# Epoch 43/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0041 - val_loss: 5.2350e-04
# Epoch 44/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0043 - val_loss: 8.6338e-04
# Epoch 45/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0045 - val_loss: 5.7291e-04
# Epoch 46/100
# 38/38 [==============================] - 5s 118ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 47/100
# 38/38 [==============================] - 4s 107ms/step - loss: 0.0038 - val_loss: 7.2790e-04
# Epoch 48/100
# 38/38 [==============================] - 4s 119ms/step - loss: 0.0039 - val_loss: 5.7072e-04
# Epoch 49/100
# 38/38 [==============================] - 4s 109ms/step - loss: 0.0035 - val_loss: 5.4016e-04
# Epoch 50/100
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0038 - val_loss: 5.1835e-04
# Epoch 51/100
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 52/100
# 38/38 [==============================] - 5s 133ms/step - loss: 0.0035 - val_loss: 5.3840e-04
# Epoch 53/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 54/100
# 38/38 [==============================] - 5s 120ms/step - loss: 0.0034 - val_loss: 9.2972e-04
# Epoch 55/100
# 38/38 [==============================] - 4s 107ms/step - loss: 0.0037 - val_loss: 5.1062e-04
# Epoch 56/100
# 38/38 [==============================] - 4s 113ms/step - loss: 0.0030 - val_loss: 5.1558e-04
# Epoch 57/100
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0031 - val_loss: 5.7818e-04
# Epoch 58/100
# 38/38 [==============================] - 4s 111ms/step - loss: 0.0033 - val_loss: 6.3595e-04
# Epoch 59/100
# 38/38 [==============================] - 4s 108ms/step - loss: 0.0031 - val_loss: 5.9042e-04
# Epoch 60/100
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0035 - val_loss: 8.7496e-04
# Epoch 61/100
# 38/38 [==============================] - 4s 105ms/step - loss: 0.0029 - val_loss: 7.3655e-04
# Epoch 62/100
# 38/38 [==============================] - 4s 114ms/step - loss: 0.0026 - val_loss: 8.5732e-04
# Epoch 63/100
# 38/38 [==============================] - 4s 107ms/step - loss: 0.0030 - val_loss: 6.1309e-04
# Epoch 64/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0029 - val_loss: 8.3194e-04
# Epoch 65/100
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 66/100
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 67/100
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 68/100
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 69/100
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0028 - val_loss: 6.6797e-04
# Epoch 70/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.0023 - val_loss: 5.7285e-04
# Epoch 71/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 72/100
# 38/38 [==============================] - 4s 105ms/step - loss: 0.0026 - val_loss: 5.3812e-04
# Epoch 73/100
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0026 - val_loss: 6.7167e-04
# Epoch 74/100
# 38/38 [==============================] - 4s 108ms/step - loss: 0.0024 - val_loss: 6.5868e-04
# Epoch 75/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.0024 - val_loss: 9.6232e-04
# Epoch 76/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0024 - val_loss: 5.0891e-04
# Epoch 77/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0025 - val_loss: 8.1092e-04
# Epoch 78/100
# 38/38 [==============================] - 4s 111ms/step - loss: 0.0024 - val_loss: 4.6883e-04
# Epoch 79/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0021 - val_loss: 8.1795e-04
# Epoch 80/100
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0022 - val_loss: 5.6813e-04
# Epoch 81/100
# 38/38 [==============================] - 4s 111ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 82/100
# 38/38 [==============================] - 4s 107ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 83/100
# 38/38 [==============================] - 4s 106ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 84/100
# 38/38 [==============================] - 4s 108ms/step - loss: 0.0023 - val_loss: 6.2103e-04
# Epoch 85/100
# 38/38 [==============================] - 5s 121ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 86/100
# 38/38 [==============================] - 5s 128ms/step - loss: 0.0022 - val_loss: 5.3931e-04
# Epoch 87/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0019 - val_loss: 4.7681e-04
# Epoch 88/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 89/100
# 38/38 [==============================] - 4s 110ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 90/100
# 38/38 [==============================] - 4s 106ms/step - loss: 0.0022 - val_loss: 4.4333e-04
# Epoch 91/100
# 38/38 [==============================] - 4s 105ms/step - loss: 0.0020 - val_loss: 6.7520e-04
# Epoch 92/100
# 38/38 [==============================] - 4s 105ms/step - loss: 0.0021 - val_loss: 4.7038e-04
# Epoch 93/100
# 38/38 [==============================] - 5s 132ms/step - loss: 0.0018 - val_loss: 6.7437e-04
# Epoch 94/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0019 - val_loss: 6.0714e-04
# Epoch 95/100
# 38/38 [==============================] - 5s 121ms/step - loss: 0.0020 - val_loss: 6.6774e-04
# Epoch 96/100
# 38/38 [==============================] - 5s 121ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 97/100
# 38/38 [==============================] - 4s 114ms/step - loss: 0.0019 - val_loss: 6.2969e-04
# Epoch 98/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 99/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0017 - val_loss: 4.6250e-04
# Epoch 100/100
# 38/38 [==============================] - 5s 127ms/step - loss: 0.0020 - val_loss: 9.0035e-04

# %% [markdown]
# ### Prepare test dataset

# %%
data = pd.concat((train_df['Open'],test_df['Open']),axis=0)

# %%
test_input = data.iloc[len(data) - len(test_df) - time : ].values
test_input.shape
# Out:
# (80,)

# %%
test_input = test_input.reshape(-1,1)
test_input.shape
# Out:
# (80, 1)

# %%
test_scaled = scaler.transform(test_input)

# %% [markdown]
# #### Create test data set

# %%
x_test = []
for i in range(time,test_scaled.shape[0]):
    x_test.append(test_scaled[i - time: i,0 ])
x_test = np.array(x_test)
x_test.shape
# Out:
# (20, 60)

# %%
x_test = np.reshape(x_test,newshape=(x_test.shape[0],x_test.shape[1],1))
x_test.shape
# Out:
# (20, 60, 1)

# %%
y_test = test_df.loc[:,"Open"].values

# %% [markdown]
# ### Model Prediction

# %%
y_pred = model.predict(x_test)
# Out:
# 1/1 [==============================] - 6s 6s/step

# %%
y_pred = scaler.inverse_transform(y_pred)

# %%
output = model.evaluate(x=x_test,y=y_test)
# Out:
# 1/1 [==============================] - 3s 3s/step - loss: 650793.3750

# %%
plt.plot(y_test, color = 'red', label = 'Real price')
plt.plot(y_pred, color = 'blue', label = 'Predicted price')

plt.title('Google Stock price prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
